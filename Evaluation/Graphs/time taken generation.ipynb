# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import numpy as np

# %%
time_taken_all = """

21.68950725
21.19092584
15.53403306
20.68519616
34.74250078
29.71144843
25.03452706
19.52075934
36.1400156
17.53044057
15.77388525
20.80101633
15.67519641
18.25082016
19.42831898
15.74177289
15.11699486
17.8871305
21.37004566
13.49663544
19.42090034
31.44824505
22.40297723
19.00135326
26.78052735
25.36073971
14.25789309
22.20635653
21.49074364
17.89799547
23.44466877


"""

# Convert the text into a list
time_taken = time_taken_all.strip().split("\n")
time_taken = [float(value) for value in time_taken]
# Output the list
print(time_taken)
print (len(time_taken))
# Out:
# [21.68950725, 21.19092584, 15.53403306, 20.68519616, 34.74250078, 29.71144843, 25.03452706, 19.52075934, 36.1400156, 17.53044057, 15.77388525, 20.80101633, 15.67519641, 18.25082016, 19.42831898, 15.74177289, 15.11699486, 17.8871305, 21.37004566, 13.49663544, 19.42090034, 31.44824505, 22.40297723, 19.00135326, 26.78052735, 25.36073971, 14.25789309, 22.20635653, 21.49074364, 17.89799547, 23.44466877]
# 31

# %%
plt.figure(figsize=(4, 5))
plt.boxplot(time_taken, vert=True, patch_artist=True)
plt.title("Time taken to generate response")
plt.ylabel("Time Taken (in seconds)")
plt.xticks([]) 
plt.ylim(10, 40) 

plt.show()

# %%
plt.rcParams.update({'font.size': 12})



# Compute key statistics
median = np.median(time_taken)
q1 = np.percentile(time_taken, 25)
q3 = np.percentile(time_taken, 75)
mean = np.mean(time_taken) 

# Create figure
plt.figure(figsize=(4.5, 5.5))


box = plt.boxplot(
    time_taken, 
    vert=True, 
    patch_artist=True,  
    boxprops=dict(facecolor="lightblue", color="black"),  
    capprops=dict(color="black"),  
    whiskerprops=dict(color="black", linestyle="--"),  
    flierprops=dict(marker='o', color='red', markersize=8, alpha=0.7),  
    medianprops=dict(color="darkblue", linewidth=2)  
)


plt.scatter(1, mean, color='red', marker='D', s=60, zorder=3, label='Mean')  

# Titles and Labels
plt.title("Time taken to generate response")
plt.ylabel("Time Taken (in seconds)")
plt.xticks([1], ["Response Time"])  

# Show grid for clarity
plt.grid(axis="y", linestyle="--", alpha=0.6)


plt.ylim(10, 40)


plt.show()

# %%
time_taken_all2 = """

1.922808886
1.57779026
1.017548561
1.349993229
1.821234226
0.705074549
0.712204218
0.854778051
3.491336823
0.799505711
1.637495518
0.485908747
0.977039099
0.83627367
0.736282587
0.591580153
0.520186663
3.9423666
0.529092073
0.712924004
0.549293995
0.830361128
0.504445553
0.52730298
1.437425852



"""

# Convert the text into a list
time_taken2 = time_taken_all2.strip().split("\n")
time_taken2 = [float(value) for value in time_taken]
# Output the list
print(time_taken2)
print (len(time_taken2))
# Out:
# [21.68950725, 21.19092584, 15.53403306, 20.68519616, 34.74250078, 29.71144843, 25.03452706, 19.52075934, 36.1400156, 17.53044057, 15.77388525, 20.80101633, 15.67519641, 18.25082016, 19.42831898, 15.74177289, 15.11699486, 17.8871305, 21.37004566, 13.49663544, 19.42090034, 31.44824505, 22.40297723, 19.00135326, 26.78052735, 25.36073971, 14.25789309, 22.20635653, 21.49074364, 17.89799547, 23.44466877]
# 31
